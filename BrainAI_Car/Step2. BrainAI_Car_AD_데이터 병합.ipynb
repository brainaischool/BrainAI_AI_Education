# %% [markdown]
# ## AI + 피지컬 컴퓨팅: BrainAI Car 자율주행 프로젝트
# ### BrainAI Car 자율주행 [분리하여 획득된 데이터 병합 도구] 실행 프로그램
#
# #### 실행 파일
# - 실행 파일: Step2. BrainAI_Car_AD_데이터 병합.ipynb
# - 필요 모듈: /utils/data_merge.py
#
# 활동 제목: BrainAI Car 도로인식 자율주행용으로 획득된 데이터 병합하기 <br>
# 활동 설명: BrainAI Car를 운전하면서 획득한 데이터를 하나의 폴더로 병합합니다.
#
# #### 주요 기능:
# - data 폴더 내 여러 날짜 폴더(예: 20250704_183905)의 데이터를 하나로 병합
# - 중복 파일명 자동 처리 (타임스탬프 추가)
# - 병합된 데이터를 data_merged_laneD1/ 폴더에 저장
# - 데이터 정리의 중요성 알기
#
# #### 실행 방법:
# 1. 셀을 위에서부터 차례대로 실행
# 2. 각 셀의 설명을 읽고 이해하기
# 3. 결과를 확인하며 진행하기

# %%
# 1. 필요 모듈 불러오기

from utils import data_merge
# Out:
# C:\BrainAI\vbrainai_car\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# 2. 폴더 경로 설정: 어떤 폴더의 데이터를 합칠지 정하기

data_root = "data_laneD1" # 원본 데이터가 있는 폴더 (여러 날짜 폴더들이 들어있음)
target_dir = "data_merged_laneD1" # 병합한 결과를 저장할 폴더

print("\n💡 폴더 경로를 바꾸고 싶다면:")
print("   위의 data_root와 target_dir 값을 수정하세요")
# Out:
# 💡 폴더 경로를 바꾸고 싶다면:
#    위의 data_root와 target_dir 값을 수정하세요

# %%
# 3. 데이터 병합 실행!

data_merge.merge_data_folders(data_root, target_dir) # 병합 함수 실행
# Out:
# ...
# 🤖 BrainAI Car 자율주행 - 데이터 병합 시작
# ...
#
# ❌ 오류: data 폴더를 찾을 수 없습니다: data_laneD1
#
# 💡 힌트:
#    1. 폴더 이름을 확인해보세요
#    2. 프로젝트 루트 폴더에서 실행하고 있는지 확인하세요

# %%
# 4. 완료! 폴더 확인 및 다음 단계 안내

print("\n 무엇을 했나요?")
print("   1. 여러 날짜 폴더의 이미지와 JSON 파일을 찾았어요")
print("   2. 파일명이 중복되는 경우 자동으로 이름을 바꿨어요")
print("   3. 모든 데이터를 하나의 폴더에 깔끔하게 정리했어요")

print("\n 확인해보기:")
print(f"   파일 탐색기에서 '{target_dir}' 폴더를 열어보세요!")
print("   ├── images/ 폴더: 모든 이미지")
print("   └── annotations/ 폴더: 모든 JSON 파일")

print("\n 다음 단계:")
print("   Step3. BrainAI_Car_AD_데이터 정제 노트북을 실행해서")
print("   데이터 정제 작업을 수행합니다. ")
# Out:
#  무엇을 했나요?
#    1. 여러 날짜 폴더의 이미지와 JSON 파일을 찾았어요
#    2. 파일명이 중복되는 경우 자동으로 이름을 바꿨어요
#    3. 모든 데이터를 하나의 폴더에 깔끔하게 정리했어요
#
#  확인해보기:
#    파일 탐색기에서 'data_laneD1_merged' 폴더를 열어보세요!
#    ├── images/ 폴더: 모든 이미지
#    └── annotations/ 폴더: 모든 JSON 파일
#
#  다음 단계:
#    Step3. BrainAI_Car_AD_데이터 정제 노트북을 실행해서
#    데이터 정제 작업을 수행합니다.

# %% [markdown]
# ## 버전 정보
# - __version__ = 'BrainAI_Car_2025.1.0.0'
# - __author__ = 'BrainAI Co,.Ltd.'
# - __description__ = 'BrainAI Autonomous Driving Project - Data Merge'
