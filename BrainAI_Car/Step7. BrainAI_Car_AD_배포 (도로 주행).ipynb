# %% [markdown]
# ## AI + 피지컬 컴퓨팅: BrainAI Car 자율주행 프로젝트
# ### BrainAI Car 자율주행 [도로 주행] 실행 프로그램
#
# #### 실행 파일
# - 실행 파일: Step7. BrainAI_Car_AD_배포 (도로 주행).ipynb
# - 필요 모듈: 없음
#
# 활동 제목: BrainAI Car 자율주행 테스트 하기 <br>
# 활동 설명: BrainAI Car의 도로인식 자율주행 AI 모델을  <br>
#           활용하여 도로(Playfiled)에서 자율을 주행 테스트 합니다.
# #### 주요 기능:
# - 정해진 속도로 주행하면서
# - 훈련된 AI 모델로 도로를 따라 주행합니다.
#
# #### 실행 방법:
# 1. 셀을 위에서부터 차례대로 실행
# 2. 각 셀의 설명을 읽고 이해하기
# 3. 결과를 확인하며 진행하기

# %%
from utils.deployment import BrainAICarDeployment
# Out:
# C:\BrainAI\vbrainai_car\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# 메인 함수
def main():
    """메인 함수 - 설정만 하고 실행"""
    
    # ============================================
    # 여기만 수정하세요!
    # ============================================
    
    # 비디오 소스 설정
    # IP 카메라: "https://172.30.1.12:8080/video"
    # USB 카메라: 0, 1, 2 등
    # video_source = "https://172.30.1.12:8080/video"
    video_source = 0
    
    # 초기 속도 (181~1023)
    initial_speed = 450
    
    # 시리얼 통신 사용 여부
    use_serial = False #True
    
    # ============================================
    
    # 자율주행 시스템 생성 및 실행
    car = BrainAICarDeployment(
        video_source=video_source,
        initial_speed=initial_speed,
        use_serial=use_serial,
        show_messages=True
    )
    
    car.run()

# %%
if __name__ == '__main__':
    main()
# Out:
# 2025-11-13 20:25:22,369 - utils.deployment - INFO - BrainAICarDeployment 초기화 완료
# 2025-11-13 20:25:22,371 - utils.deployment - INFO - ============================================================
# 2025-11-13 20:25:22,371 - utils.deployment - INFO - BrainAI Car 자율주행 시스템 시작
# 2025-11-13 20:25:22,372 - utils.deployment - INFO - ============================================================
# 2025-11-13 20:25:22,373 - utils.deployment - INFO - 조작 키:
# 2025-11-13 20:25:22,374 - utils.deployment - INFO -   Q: 종료
# 2025-11-13 20:25:22,375 - utils.deployment - INFO -   S: 시작/정지
# 2025-11-13 20:25:22,375 - utils.deployment - INFO -   1: laneD1 모델 전환
# 2025-11-13 20:25:22,375 - utils.deployment - INFO -   2: laneD2 모델 전환
# 2025-11-13 20:25:22,377 - utils.deployment - INFO - ============================================================
# 2025-11-13 20:25:22,378 - utils.deployment - INFO - 컴포넌트 초기화 중...
# ...
